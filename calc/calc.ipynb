# %%
import tkinter as tk

def on_button_click(event):
    button_text = event.widget.cget("text")
    print(f"{button_text}ボタンが押されました")
    event.widget.config(fg="red")

root = tk.Tk()
root.title("計算機")

for i in range(0,10):
    button = tk.Button(root, text=str(i))
    button.grid(row=i//3,column=i%3)
    button.bind("<Button-1>",on_button_click)
#button.pack()

root.mainloop()
# Out:
# 8ボタンが押されました
# 8ボタンが押されました
# 8ボタンが押されました
# 4ボタンが押されました
# 0ボタンが押されました
# 1ボタンが押されました
# 2ボタンが押されました
# 5ボタンが押されました
# 5ボタンが押されました

# %%
import tkinter as tk
root = tk.Tk()
root.title("計算機")
button = tk.Button(root, text="1")
print(button)
button.bind("",callback)
# Out:
# .!button
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       4 button = tk.Button(root, text="1")
#       5 print(button)
# ----> 6 button.bind("",callback)
#
# NameError: name 'callback' is not defined
